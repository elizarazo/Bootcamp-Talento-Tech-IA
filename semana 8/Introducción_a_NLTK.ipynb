# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)

# %%
import nltk
#nltk.download()

# %%
# División de una oración en palabras individuales.

# Importar las bibliotecas necesarias
import nltk
from nltk.tokenize import word_tokenize

# Descargar los datos necesarios para la tokenización
nltk.download('punkt')

# División de una oración en palabras individuales
sentence = "NLTK es una biblioteca de procesamiento de lenguaje natural en Python"
tokens = word_tokenize(sentence)
print(tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['NLTK', 'es', 'una', 'biblioteca', 'de', 'procesamiento', 'de', 'lenguaje', 'natural', 'en', 'Python']

# %%
# Hacer a mano la función word_tokenize con un ciclo

# %%
#Reducción de palabras a su forma base con NLTK
from nltk.stem import PorterStemmer

#words = ['trabanjando', 'trabajos', 'trabajador']
words = ['running', 'plays', 'jumped']
stemmer = PorterStemmer()
stem = [stemmer.stem(word) for word in words]
print(stem)
# Out:
# ['run', 'play', 'jump']

# %%
#Etiquetado gramatical de palabras en una oración.

# Importar las bibliotecas necesarias
import nltk
from nltk import pos_tag
from nltk.tokenize import word_tokenize

# Descargar los datos necesarios para el etiquetado gramatical
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')

# Etiquetado gramatical de palabras en una oración
sentence = "NLTK es una biblioteca de procesamiento de lenguaje natural en Python"
tokens = word_tokenize(sentence)
tagged_words = pos_tag(tokens)
print(tagged_words)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [('NLTK', 'NNP'), ('es', 'CC'), ('una', 'JJ'), ('biblioteca', 'NN'), ('de', 'IN'), ('procesamiento', 'FW'), ('de', 'FW'), ('lenguaje', 'FW'), ('natural', 'JJ'), ('en', 'FW'), ('Python', 'NN')]

# %% [markdown]
# Utilizando

# %%
import nltk
import random
data = [
    ("I love this movie.", "positive"),
    ("This movie is terrible", "negative"),
    ("This movie is great", "positive"),
    ("I dislike this movie", "negative"),
    ("This film is amazing", "positive"),
    ("I can't stand watching this movie", "negative"),
    ("The acting in this movie is phenomenal", "positive"),
    ("I regret wasting my time on this film", "negative"),
    ("I thoroughly enjoyed this movie", "positive"),
    ("the plot of this movie was captivating", "positive"),
    ("I found the caracters in thos film to be very engaging", "positive"),
    ("The special effects in this movie were impressive", "positive"),
    ("The storyline was predictableand unoriginal", "negative"),
    ("I was disappointed by the lack of character development in this movie", "negative"),
    ("The visuals in this movie were stunning", "positive")
]

# %% [markdown]
# Preprocesamiento de datos

# %%
# Preprocesamiento de datos
def preprocess(text):
    tokens = nltk.word_tokenize(text)
    return {word: True for word in tokens}

# %% [markdown]
# Aplicamos el procesamiento a los datos

# %%
nltk.download('punkt')
# Aplicamos el procesamiento a los datos
features = [(preprocess(text), label) for (text, label) in data]

# Dividimos los datos en conjuntos de entrenamiento y prueba
train_set, test_set = features[:16], features[16:]

# Entrenamos el clasificador
classifier = nltk.NaiveBayesClassifier.train(train_set)

# Evaluamos el clasificador en el conjunto de prueba
accuracy = nltk.classify.accuracy(classifier, test_set)
print("Accuracy:", accuracy)

# Clasificamos un nuevo texto
new_text = "This movie is amazing"
new_text_features = preprocess(new_text)
predicted_label = classifier.classify(new_text_features)
print("Prediction:", predicted_label)
# Out:
# Accuracy: 0
# Prediction: positive
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Preguntas de comprensión:

# %% [markdown]
#
#
# 1.   ¿Qué tarea realiza el código proporcionado? Se trata de un algoritmo utilizado para hacer clasificación de texto calculando la probabilidad que un texto sea parte de una categoríarevisando las características del mismo.
# 2. ¿Cuál es el propósito del preprocesamiento de datos en este contexto? El proposito del preprocesamiento es el de convertir un texto a una representación que pueda ser usada para aplicar a un algoritmo de aprendizaje automático.
# 3.  ¿Qué función de NLTK se utiliza para tokenizar el texto? La función de NLTK que se utiliza para tokenizar el texto es word_tokenize. Toma un texto a manera de entrada y debe devolvet una lista de "tokens", que son las palabras individuales en el texto.
# 4. ¿Cuál es el propósito de dividir los datos en conjuntos de entrenamiento y prueba? El propósito principal es evaluar de manera confiable el rendimiento de un modelo y evitar el sobreajuste.
# 5. ¿Qué algoritmo de clasificación se utiliza en este código? nltk.NaiveBayesClassifier es un algoritmo de clasificación de texto que utiliza el teorema de Bayes para calcular la probabilidad de que un texto pertenezca a una categoría en particular.
# 6. ¿Cómo se evalúa la precisión del clasificador? Se calcula el porcentaje de predicciones correctas sobre el total de predicciones realizadas. Este porcentaje es la precisión del clasificador.
# 7. ¿Qué se entiende por "Accuracy" en el contexto de la evaluación del clasificador? "Accuracy" (precisión) en el contexto de la evaluación del clasificador se refiere al porcentaje de predicciones correctas que el modelo ha realizado sobre el conjunto de prueba. Es una medida de qué tan bien el modelo generaliza a datos no vistos durante el entrenamiento. Una precisión más alta indica un mejor rendimiento del modelo, pero es importante considerar otras métricas y el contexto del problema para una evaluación completa.
# 8. ¿Cuál es el resultado de la clasificación del nuevo texto "This movie is amazing"? Positive

# %% [markdown]
# Ejercicios de exploración

# %% [markdown]
# 1. Modifica el conjunto de datos agregando más instancias con comentarios de películas y etiquetas de sentimientos.
# 2. Experimenta con diferentes técnicas de preprocesamiento de texto, como eliminación de stopwords o lematización, y observa cómo afecta la precisión del clasificador.
# 3. Prueba otros algoritmos de clasificación disponibles en NLTK, como clasificador de árboles de decisión o clasificador de máquinas de vectores de soporte (SVM), ycompara sus resultados con el clasificador Naive Bayes.
# 4. Crea una función para calcular métricas adicionales de evaluación del clasificador, como precisión, recall y F1-score, y aplícala al modelo entrenado.
# 5. Experimenta con la clasificación de nuevos textos ingresados manualmente y observa cómo el clasificador etiqueta diferentes comentarios de películas.

# %%
import nltk
import random
data = [
    ("I love this movie", "positive"),
    ("This movie is terrible", "negative"),
    ("This movie is great", "positive"),
    ("I dislike this movie", "negative"),
    ("This film is amazing", "positive"),
    ("I can't stand watching this movie", "negative"),
    ("The acting in this movie is phenomenal", "positive"),
    ("I regret wasting my time on this film", "negative"),
    ("I thoroughly enjoyed this movie", "positive"),
    ("This movie lacks depth and substance", "negative"),
    ("The plot of this movie was captivating", "positive"),
    ("I found the characters in this film to be very engaging", "positive"),
    ("The special effects in this movie were impressive", "positive"),
    ("The storyline was predictable and unoriginal", "negative"),
    ("I was disappointed by the lack of character development", "negative"),
    ("The cinematography in this film was stunning", "positive"),
    ("The dialogue felt forced and unnatural", "negative"),
    ("The pacing of the movie was too slow for my liking", "negative"),
    ("I was pleasantly surprised by how I enjoyed this film", "positive"),
    ("The ending left me feeling unsatisfied and confused", "negative"),
    ("This movie exceeded my expectations", "positive"),
    ("The performances by the actors were lackluster", "negative"),
    ("This film is a masterpiece", "positive"),
    ("I couldn't wait for this movie to end", "negative"),
    ("The soundtrack of this movie was beautiful", "positive"),
    ("The plot twists were very predictable", "negative"),
    ("I was on the edge of my seat the entire time", "positive"),
    ("The movie was a complete waste of time", "negative"),
    ("The visuals in this film were breathtaking", "positive"),
    ("The characters were one-dimensional", "negative"),
    ("I would watch this movie again", "positive"),
    ("The movie was too long and boring", "negative"),
    ("The director did an excellent job", "positive"),
    ("The movie failed to capture my interest", "negative"),
    ("The film had a powerful message", "positive"),
    ("The acting was subpar", "negative"),
    ("I was emotionally moved by this movie", "positive"),
    ("The movie was full of clichés", "negative"),
    ("The film was a visual feast", "positive"),
    ("The plot was hard to follow", "negative"),
    ("I highly recommend this movie", "positive"),
    ("The movie was poorly executed", "negative"),
    ("The film was thought-provoking", "positive"),
    ("The movie was a letdown", "negative"),
    ("The performances were outstanding", "positive"),
    ("The movie was forgettable", "negative"),
    ("The film was a rollercoaster of emotions", "positive"),
    ("The movie lacked originality", "negative"),
    ("The film was beautifully shot", "positive"),
    ("The movie was a disappointment", "negative"),
    ("The film was heartwarming", "positive"),
    ("The movie was poorly written", "negative"),
    ("The film was inspiring", "positive"),
    ("The movie was a mess", "negative"),
    ("The film was a joy to watch", "positive"),
    ("The movie was confusing", "negative"),
    ("The film was a triumph", "positive"),
    ("The movie was dull", "negative"),
    ("The film was a work of art", "positive"),
    ("The movie was underwhelming", "negative"),
    ("The film was captivating", "positive"),
    ("The movie was a flop", "negative"),
    ("The film was enchanting", "positive"),
    ("The movie was a disaster", "negative"),
    ("The film was mesmerizing", "positive"),
    ("The movie was a bore", "negative"),
    ("The film was a delight", "positive"),
    ("The movie was a failure", "negative"),
    ("The film was a revelation", "positive"),
    ("The movie was tedious", "negative"),
    ("The film was a gem", "positive"),
    ("The movie was lackluster", "negative"),
    ("The film was a treasure", "positive"),
    ("The movie was disappointing", "negative"),
    ("The film was a marvel", "positive"),
    ("The movie was mediocre", "negative"),
    ("The film was a spectacle", "positive"),
    ("The movie was substandard", "negative"),
    ("The film was a wonder", "positive"),
    ("The movie was unimpressive", "negative"),
    ("The film was a masterpiece", "positive"),
    ("The movie was forgettable", "negative"),
    ("The film was a tour de force", "positive"),
    ("The movie was bland", "negative"),
    ("The film was a triumph", "positive"),
    ("The movie was uninspired", "negative"),
    ("The film was a joy", "positive"),
    ("The movie was a letdown", "negative"),
    ("The film was a revelation", "positive"),
    ("The movie was a disappointment", "negative"),
    ("The film was a delight", "positive"),
    ("The movie was a failure", "negative"),
    ("The film was a marvel", "positive"),
    ("The movie was tedious", "negative"),
    ("The film was a spectacle", "positive"),
    ("The movie was dull", "negative"),
    ("The film was a wonder", "positive"),
    ("The movie was underwhelming", "negative"),
    ("The film was a treasure", "positive"),
    ("The movie was lackluster", "negative"),
    ("The film was a gem", "positive"),
    ("The movie was unimpressive", "negative"),
    ("The film was a tour de force", "positive"),
    ("The movie was substandard", "negative")
]

# %%
# Preprocesamiento de datos: tokenización y extracción de caracteristicas
def preprocess(text):
    tokens = nltk.word_tokenize(text)
    return {word: True for word in tokens}

print(preprocess("I love this movie"))
# Out:
# {'I': True, 'love': True, 'this': True, 'movie': True}

# %%
nltk.download('punkt')
# Aplicamos el procesamiento a los datos
featuresets = [(preprocess(text), label) for (text, label) in data]
print(featuresets)
# Out:
# [({'I': True, 'love': True, 'this': True, 'movie': True}, 'positive'), ({'This': True, 'movie': True, 'is': True, 'terrible': True}, 'negative'), ({'This': True, 'movie': True, 'is': True, 'great': True}, 'positive'), ({'I': True, 'dislike': True, 'this': True, 'movie': True}, 'negative'), ({'This': True, 'film': True, 'is': True, 'amazing': True}, 'positive'), ({'I': True, 'ca': True, "n't": True, 'stand': True, 'watching': True, 'this': True, 'movie': True}, 'negative'), ({'The': True, 'acting': True, 'in': True, 'this': True, 'movie': True, 'is': True, 'phenomenal': True}, 'positive'), ({'I': True, 'regret': True, 'wasting': True, 'my': True, 'time': True, 'on': True, 'this': True, 'film': True}, 'negative'), ({'I': True, 'thoroughly': True, 'enjoyed': True, 'this': True, 'movie': True}, 'positive'), ({'This': True, 'movie': True, 'lacks': True, 'depth': True, 'and': True, 'substance': True}, 'negative'), ({'The': True, 'plot': True, 'of': True, 'this': True, 'movie': True, 'was': True, 'captivating': True}, 'positive'), ({'I': True, 'found': True, 'the': True, 'characters': True, 'in': True, 'this': True, 'film': True, 'to': True, 'be': True, 'very': True, 'engaging': True}, 'positive'), ({'The': True, 'special': True, 'effects': True, 'in': True, 'this': True, 'movie': True, 'were': True, 'impressive': True}, 'positive'), ({'The': True, 'storyline': True, 'was': True, 'predictable': True, 'and': True, 'unoriginal': True}, 'negative'), ({'I': True, 'was': True, 'disappointed': True, 'by': True, 'the': True, 'lack': True, 'of': True, 'character': True, 'development': True}, 'negative'), ({'The': True, 'cinematography': True, 'in': True, 'this': True, 'film': True, 'was': True, 'stunning': True}, 'positive'), ({'The': True, 'dialogue': True, 'felt': True, 'forced': True, 'and': True, 'unnatural': True}, 'negative'), ({'The': True, 'pacing': True, 'of': True, 'the': True, 'movie': True, 'was': True, 'too': True, 'slow': True, 'for': True, 'my': True, 'liking': True}, 'negative'), ({'I': True, 'was': True, 'pleasantly': True, 'surprised': True, 'by': True, 'how': True, 'enjoyed': True, 'this': True, 'film': True}, 'positive'), ({'The': True, 'ending': True, 'left': True, 'me': True, 'feeling': True, 'unsatisfied': True, 'and': True, 'confused': True}, 'negative'), ({'This': True, 'movie': True, 'exceeded': True, 'my': True, 'expectations': True}, 'positive'), ({'The': True, 'performances': True, 'by': True, 'the': True, 'actors': True, 'were': True, 'lackluster': True}, 'negative'), ({'This': True, 'film': True, 'is': True, 'a': True, 'masterpiece': True}, 'positive'), ({'I': True, 'could': True, "n't": True, 'wait': True, 'for': True, 'this': True, 'movie': True, 'to': True, 'end': True}, 'negative'), ({'The': True, 'soundtrack': True, 'of': True, 'this': True, 'movie': True, 'was': True, 'beautiful': True}, 'positive'), ({'The': True, 'plot': True, 'twists': True, 'were': True, 'very': True, 'predictable': True}, 'negative'), ({'I': True, 'was': True, 'on': True, 'the': True, 'edge': True, 'of': True, 'my': True, 'seat': True, 'entire': True, 'time': True}, 'positive'), ({'The': True, 'movie': True, 'was': True, 'a': True, 'complete': True, 'waste': True, 'of': True, 'time': True}, 'negative'), ({'The': True, 'visuals': True, 'in': True, 'this': True, 'film': True, 'were': True, 'breathtaking': True}, 'positive'), ({'The': True, 'characters': True, 'were': True, 'one-dimensional': True}, 'negative'), ({'I': True, 'would': True, 'watch': True, 'this': True, 'movie': True, 'again': True}, 'positive'), ({'The': True, 'movie': True, 'was': True, 'too': True, 'long': True, 'and': True, 'boring': True}, 'negative'), ({'The': True, 'director': True, 'did': True, 'an': True, 'excellent': True, 'job': True}, 'positive'), ({'The': True, 'movie': True, 'failed': True, 'to': True, 'capture': True, 'my': True, 'interest': True}, 'negative'), ({'The': True, 'film': True, 'had': True, 'a': True, 'powerful': True, 'message': True}, 'positiv ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import matplotlib.pyplot as plt
# Revisar el histograma
labels = [label for (text, label) in data]
plt.figure(figsize=(8, 6))
plt.hist(labels)
plt.xlabel('Sentiment')
plt.ylabel('Frecuency')
plt.title('Distribución de Etiquetas')
plt.show()

# %%
# Histograma de palabras
from collections import Counter

# Extraer todas las palabras
all_words = []
for text, _ in data:
    all_words.extend(text.lower().split())

# Contar frecuencia de palabras
word_counts = Counter(all_words)

# Obtener las 10 palabras más comunes
top_10_words = word_counts.most_common(10)

# Crear un gráfico de barras
words, counts = zip(*top_10_words)
plt.figure(figsize=(10, 6))
plt.bar(words, counts)
plt.xlabel('Palabras')
plt.ylabel('Frecuencia')
plt.title('Top 10 Palabras Más Comunes')
plt.xticks(rotation=45)
plt.show()

import matplotlib.pyplot as plt

# Obtener las palabras y sus frecuencias
words = list(word_counts.keys())
counts = list(word_counts.values())

# Crear el histograma
plt.figure(figsize=(12, 6))
plt.bar(words, counts)
plt.xlabel('Palabras')
plt.ylabel('Frecuencia')
plt.title('Histograma de Frecuencia de Palabras')
plt.xticks(rotation=90)  # Rotar etiquetas del eje x para mejor legibilidad
plt.tight_layout()  # Ajustar el diseño para evitar que las etiquetas se superpongan
plt.show()

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt') # Download the 'punkt' resource

# Preprocesamiento de datos con stopwords
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
from nltk.corpus import stopwords # import the stopwords module
from nltk.tokenize import word_tokenize # import the word_tokenize function

def remove_stopwords(text):
  stop_words = set(stopwords.words('english')) # use the stopwords module to get stop words
  word_tokens = word_tokenize(text)
  filtered_text = [word for word in word_tokens if word.lower() not in stop_words]
  return ' '.join(filtered_text)


# Une todas las frases en un solo texto
texto = " ".join([item[0] for item in data])
data
# Define las palabras que quieres ignorar (stopwords)
stopwords_wc = set(STOPWORDS) # rename this variable to avoid overwriting the stopwords module
#stopwords_wc.update(["ejemplo", "otra", "más"])  # Agrega palabras adicionales si es necesario

# Crea la nube de palabras
wordcloud = WordCloud(width=800, height=400, background_color="white", stopwords=stopwords_wc).generate(texto)

plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Aplicamos el procesamiento a los datos
featuresets = [({'text': remove_stopwords(text)}, label) for (text, label) in data]
print(featuresets)
# Out:
# [({'text': 'love movie'}, 'positive'), ({'text': 'movie terrible'}, 'negative'), ({'text': 'movie great'}, 'positive'), ({'text': 'dislike movie'}, 'negative'), ({'text': 'film amazing'}, 'positive'), ({'text': "ca n't stand watching movie"}, 'negative'), ({'text': 'acting movie phenomenal'}, 'positive'), ({'text': 'regret wasting time film'}, 'negative'), ({'text': 'thoroughly enjoyed movie'}, 'positive'), ({'text': 'movie lacks depth substance'}, 'negative'), ({'text': 'plot movie captivating'}, 'positive'), ({'text': 'found characters film engaging'}, 'positive'), ({'text': 'special effects movie impressive'}, 'positive'), ({'text': 'storyline predictable unoriginal'}, 'negative'), ({'text': 'disappointed lack character development'}, 'negative'), ({'text': 'cinematography film stunning'}, 'positive'), ({'text': 'dialogue felt forced unnatural'}, 'negative'), ({'text': 'pacing movie slow liking'}, 'negative'), ({'text': 'pleasantly surprised enjoyed film'}, 'positive'), ({'text': 'ending left feeling unsatisfied confused'}, 'negative'), ({'text': 'movie exceeded expectations'}, 'positive'), ({'text': 'performances actors lackluster'}, 'negative'), ({'text': 'film masterpiece'}, 'positive'), ({'text': "could n't wait movie end"}, 'negative'), ({'text': 'soundtrack movie beautiful'}, 'positive'), ({'text': 'plot twists predictable'}, 'negative'), ({'text': 'edge seat entire time'}, 'positive'), ({'text': 'movie complete waste time'}, 'negative'), ({'text': 'visuals film breathtaking'}, 'positive'), ({'text': 'characters one-dimensional'}, 'negative'), ({'text': 'would watch movie'}, 'positive'), ({'text': 'movie long boring'}, 'negative'), ({'text': 'director excellent job'}, 'positive'), ({'text': 'movie failed capture interest'}, 'negative'), ({'text': 'film powerful message'}, 'positive'), ({'text': 'acting subpar'}, 'negative'), ({'text': 'emotionally moved movie'}, 'positive'), ({'text': 'movie full clichés'}, 'negative'), ({'text': 'film visual feast'}, 'positive'), ({'text': 'plot hard follow'}, 'negative'), ({'text': 'highly recommend movie'}, 'positive'), ({'text': 'movie poorly executed'}, 'negative'), ({'text': 'film thought-provoking'}, 'positive'), ({'text': 'movie letdown'}, 'negative'), ({'text': 'performances outstanding'}, 'positive'), ({'text': 'movie forgettable'}, 'negative'), ({'text': 'film rollercoaster emotions'}, 'positive'), ({'text': 'movie lacked originality'}, 'negative'), ({'text': 'film beautifully shot'}, 'positive'), ({'text': 'movie disappointment'}, 'negative'), ({'text': 'film heartwarming'}, 'positive'), ({'text': 'movie poorly written'}, 'negative'), ({'text': 'film inspiring'}, 'positive'), ({'text': 'movie mess'}, 'negative'), ({'text': 'film joy watch'}, 'positive'), ({'text': 'movie confusing'}, 'negative'), ({'text': 'film triumph'}, 'positive'), ({'text': 'movie dull'}, 'negative'), ({'text': 'film work art'}, 'positive'), ({'text': 'movie underwhelming'}, 'negative'), ({'text': 'film captivating'}, 'positive'), ({'text': 'movie flop'}, 'negative'), ({'text': 'film enchanting'}, 'positive'), ({'text': 'movie disaster'}, 'negative'), ({'text': 'film mesmerizing'}, 'positive'), ({'text': 'movie bore'}, 'negative'), ({'text': 'film delight'}, 'positive'), ({'text': 'movie failure'}, 'negative'), ({'text': 'film revelation'}, 'positive'), ({'text': 'movie tedious'}, 'negative'), ({'text': 'film gem'}, 'positive'), ({'text': 'movie lackluster'}, 'negative'), ({'text': 'film treasure'}, 'positive'), ({'text': 'movie disappointing'}, 'negative'), ({'text': 'film marvel'}, 'positive'), ({'text': 'movie mediocre'}, 'negative'), ({'text': 'film spectacle'}, 'positive'), ({'text': 'movie substandard'}, 'negative'), ({'text': 'film wonder'}, 'positive'), ({'text': 'movie unimpressive'}, 'negative'), ({'text': 'film masterpiece'}, 'positive'), ({'text': 'movie forgettable'}, 'negative'), ({'text': 'film tour de force'}, 'positive'), ({'text': 'movie bland'}, 'negative'), ({'text': 'film triumph' ...

# %%
# Dividimos los datos en conjuntos de entrenamiento y prueba
train_set, test_set = featuresets[:80], featuresets[80:]
print(train_set)
print(test_set)
# Out:
# [({'text': 'love movie'}, 'positive'), ({'text': 'movie terrible'}, 'negative'), ({'text': 'movie great'}, 'positive'), ({'text': 'dislike movie'}, 'negative'), ({'text': 'film amazing'}, 'positive'), ({'text': "ca n't stand watching movie"}, 'negative'), ({'text': 'acting movie phenomenal'}, 'positive'), ({'text': 'regret wasting time film'}, 'negative'), ({'text': 'thoroughly enjoyed movie'}, 'positive'), ({'text': 'movie lacks depth substance'}, 'negative'), ({'text': 'plot movie captivating'}, 'positive'), ({'text': 'found characters film engaging'}, 'positive'), ({'text': 'special effects movie impressive'}, 'positive'), ({'text': 'storyline predictable unoriginal'}, 'negative'), ({'text': 'disappointed lack character development'}, 'negative'), ({'text': 'cinematography film stunning'}, 'positive'), ({'text': 'dialogue felt forced unnatural'}, 'negative'), ({'text': 'pacing movie slow liking'}, 'negative'), ({'text': 'pleasantly surprised enjoyed film'}, 'positive'), ({'text': 'ending left feeling unsatisfied confused'}, 'negative'), ({'text': 'movie exceeded expectations'}, 'positive'), ({'text': 'performances actors lackluster'}, 'negative'), ({'text': 'film masterpiece'}, 'positive'), ({'text': "could n't wait movie end"}, 'negative'), ({'text': 'soundtrack movie beautiful'}, 'positive'), ({'text': 'plot twists predictable'}, 'negative'), ({'text': 'edge seat entire time'}, 'positive'), ({'text': 'movie complete waste time'}, 'negative'), ({'text': 'visuals film breathtaking'}, 'positive'), ({'text': 'characters one-dimensional'}, 'negative'), ({'text': 'would watch movie'}, 'positive'), ({'text': 'movie long boring'}, 'negative'), ({'text': 'director excellent job'}, 'positive'), ({'text': 'movie failed capture interest'}, 'negative'), ({'text': 'film powerful message'}, 'positive'), ({'text': 'acting subpar'}, 'negative'), ({'text': 'emotionally moved movie'}, 'positive'), ({'text': 'movie full clichés'}, 'negative'), ({'text': 'film visual feast'}, 'positive'), ({'text': 'plot hard follow'}, 'negative'), ({'text': 'highly recommend movie'}, 'positive'), ({'text': 'movie poorly executed'}, 'negative'), ({'text': 'film thought-provoking'}, 'positive'), ({'text': 'movie letdown'}, 'negative'), ({'text': 'performances outstanding'}, 'positive'), ({'text': 'movie forgettable'}, 'negative'), ({'text': 'film rollercoaster emotions'}, 'positive'), ({'text': 'movie lacked originality'}, 'negative'), ({'text': 'film beautifully shot'}, 'positive'), ({'text': 'movie disappointment'}, 'negative'), ({'text': 'film heartwarming'}, 'positive'), ({'text': 'movie poorly written'}, 'negative'), ({'text': 'film inspiring'}, 'positive'), ({'text': 'movie mess'}, 'negative'), ({'text': 'film joy watch'}, 'positive'), ({'text': 'movie confusing'}, 'negative'), ({'text': 'film triumph'}, 'positive'), ({'text': 'movie dull'}, 'negative'), ({'text': 'film work art'}, 'positive'), ({'text': 'movie underwhelming'}, 'negative'), ({'text': 'film captivating'}, 'positive'), ({'text': 'movie flop'}, 'negative'), ({'text': 'film enchanting'}, 'positive'), ({'text': 'movie disaster'}, 'negative'), ({'text': 'film mesmerizing'}, 'positive'), ({'text': 'movie bore'}, 'negative'), ({'text': 'film delight'}, 'positive'), ({'text': 'movie failure'}, 'negative'), ({'text': 'film revelation'}, 'positive'), ({'text': 'movie tedious'}, 'negative'), ({'text': 'film gem'}, 'positive'), ({'text': 'movie lackluster'}, 'negative'), ({'text': 'film treasure'}, 'positive'), ({'text': 'movie disappointing'}, 'negative'), ({'text': 'film marvel'}, 'positive'), ({'text': 'movie mediocre'}, 'negative'), ({'text': 'film spectacle'}, 'positive'), ({'text': 'movie substandard'}, 'negative'), ({'text': 'film wonder'}, 'positive'), ({'text': 'movie unimpressive'}, 'negative')]
# [({'text': 'film masterpiece'}, 'positive'), ({'text': 'movie forgettable'}, 'negative'), ({'text': 'film tour de force'}, 'positive'), ({'text': 'movie bland'}, 'negative'), ({'text': 'film triumph'}, 'positive'), ({'text': 'movie uninspired'}, 'negative'), ({'text': 'film joy'}, 'positive'), ({'text': 'movie letdown'}, 'negative'), ({'text': 'film revelation'}, 'positive'), ({'text': 'movie disappointment'}, 'negative'), ({'text': 'film delight'}, 'positive'), ({'text': 'movie failure'}, 'negative'), ({'text': 'film marvel'}, 'positive'), ({'text': 'movie tedious'}, 'negative'), ({'text': 'film spectacle'}, 'positive'), ({'text': 'movie dull'}, 'negative'), ({'text': 'film wonder'}, 'positive'), ({'text': 'movie underwhelming'}, 'negative'), ({'text': 'film treasure'}, 'positive'), ({'text': 'movie lackluster'}, 'negative'), ({'text': 'film gem'}, 'positive'), ({'text': 'movie unimpressive'}, 'negative'), ({'text': 'film tour de force'}, 'positive'), ({'text': 'movie substandard'}, 'negative')]

# %%
# Entrenamos el clasificador
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
# Evaluamos el clasificador en el conjunto de prueba
accuracy = nltk.classify.accuracy(classifier, test_set)
print("Accuracy:", accuracy)

# Evaluamos el clasificador en el conjunto de entrenamiento
accuracy = nltk.classify.accuracy(classifier, train_set)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9166666666666666
# Accuracy: 1.0

# %%
# Clasificamos un nuevo texto
new_text = "movie adorable"
new_text_features = {'text': remove_stopwords(new_text)} # Convert to dictionary
predicted_label = classifier.classify(new_text_features)
print("Prediction:", predicted_label)

# Clasificamos un nuevo texto
new_text = "movie great"
new_text_features = {'text': remove_stopwords(new_text)} # Convert to dictionary
predicted_label = classifier.classify(new_text_features)
print("Prediction:", predicted_label)

# Clasificamos un nuevo texto
new_text = "thoroughly enjoyed movie"
new_text_features = {'text': remove_stopwords(new_text)} # Convert to dictionary
predicted_label = classifier.classify(new_text_features)
print("Prediction:", predicted_label)

# Clasificamos un nuevo texto
new_text = "movie lacks depth substance"
new_text_features = {'text': remove_stopwords(new_text)} # Convert to dictionary
predicted_label = classifier.classify(new_text_features)
print("Prediction:", predicted_label)
# Out:
# Prediction: positive
# Prediction: positive
# Prediction: positive
# Prediction: negative

# %%
#from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

def remove_stopwords(text):
  stop_words = set(stopwords.words('english'))
  word_tokens = word_tokenize(text) #Tokenize the input text
  filtered_text = [word for word in word_tokens if word.lower() not in stop_words]
  return ' '.join(filtered_text)

# Iterate over each comment in the data list
for comment, sentiment in data:
    filtered_comment = remove_stopwords(comment)
    print(f"Original: {comment}")
    print(f"Filtered: {filtered_comment}\n")
# Out:
# Original: I love this movie
# Filtered: love movie
#
# Original: This movie is terrible
# Filtered: movie terrible
#
# Original: This movie is great
# Filtered: movie great
#
# Original: I dislike this movie
# Filtered: dislike movie
#
# Original: This film is amazing
# Filtered: film amazing
#
# Original: I can't stand watching this movie
# Filtered: ca n't stand watching movie
#
# Original: The acting in this movie is phenomenal
# Filtered: acting movie phenomenal
#
# Original: I regret wasting my time on this film
# Filtered: regret wasting time film
#
# Original: I thoroughly enjoyed this movie
# Filtered: thoroughly enjoyed movie
#
# Original: This movie lacks depth and substance
# Filtered: movie lacks depth substance
#
# Original: The plot of this movie was captivating
# Filtered: plot movie captivating
#
# Original: I found the characters in this film to be very engaging
# Filtered: found characters film engaging
#
# Original: The special effects in this movie were impressive
# Filtered: special effects movie impressive
#
# Original: The storyline was predictable and unoriginal
# Filtered: storyline predictable unoriginal
#
# Original: I was disappointed by the lack of character development
# Filtered: disappointed lack character development
#
# Original: The cinematography in this film was stunning
# Filtered: cinematography film stunning
#
# Original: The dialogue felt forced and unnatural
# Filtered: dialogue felt forced unnatural
#
# Original: The pacing of the movie was too slow for my liking
# Filtered: pacing movie slow liking
#
# Original: I was pleasantly surprised by how I enjoyed this film
# Filtered: pleasantly surprised enjoyed film
#
# Original: The ending left me feeling unsatisfied and confused
# Filtered: ending left feeling unsatisfied confused
#
# Original: This movie exceeded my expectations
# Filtered: movie exceeded expectations
#
# Original: The performances by the actors were lackluster
# Filtered: performances actors lackluster
#
# Original: This film is a masterpiece
# Filtered: film masterpiece
#
# Original: I couldn't wait for this movie to end
# Filtered: could n't wait movie end
#
# Original: The soundtrack of this movie was beautiful
# Filtered: soundtrack movie beautiful
#
# Original: The plot twists were very predictable
# Filtered: plot twists predictable
#
# Original: I was on the edge of my seat the entire time
# Filtered: edge seat entire time
#
# Original: The movie was a complete waste of time
# Filtered: movie complete waste time
#
# Original: The visuals in this film were breathtaking
# Filtered: visuals film breathtaking
#
# Original: The characters were one-dimensional
# Filtered: characters one-dimensional
#
# Original: I would watch this movie again
# Filtered: would watch movie
#
# Original: The movie was too long and boring
# Filtered: movie long boring
#
# Original: The director did an excellent job
# Filtered: director excellent job
#
# Original: The movie failed to capture my interest
# Filtered: movie failed capture interest
#
# Original: The film had a powerful message
# Filtered: film powerful message
#
# Original: The acting was subpar
# Filtered: acting subpar
#
# Original: I was emotionally moved by this movie
# Filtered: emotionally moved movie
#
# Original: The movie was full of clichés
# Filtered: movie full clichés
#
# Original: The film was a visual feast
# Filtered: film visual feast
#
# Original: The plot was hard to follow
# Filtered: plot hard follow
#
# Original: I highly recommend this movie
# Filtered: highly recommend movie
#
# Original: The movie was poorly executed
# Filtered: movie poorly executed
#
# Original: The film was thought-provoking
# Filtered: film thought-provoking
#
# Original: The movie was a letdown
# Filtered: movie letdown
#
# Original: The performances were outstanding
# Filtered: performances outstanding
#
# Original: The movie was forgettable
# Filtered: movie forgettable
#
# Original: The film was a rollercoaster of emotions
# Filtered: film rollercoaster emotions
#
# Original: The movie lacked originality
# Filtered: movie lacked originality
#
# Original: The film was beautifully shot
# Filtered: film beautifully shot
#
# Original: The movie was a disappointment
# Filtered: movie disappointment
#
# Original: The film was heartwarming
# Filtered: film heartwarming
#
# Original: The movie was poorly written
# Filtered: movie poorly written
#
# Original: The film was inspiring
# Filtered: film inspiring
#
# Original: The movie was a mess
# Filtered: movie mess
#
# Original: The film was a joy to watch
# Filtered: film joy watch
#
# Original: The movie was confusing
# Filtered: movie confusing
#
# Original: The film was a triumph
# Filtered: film triumph
#
# Original: The movie was dull
# Filtered: movie dull
#
# Original: The film was a work of art
# Filtered: film work art
#
# Original: The movie was underwhelming
# Filtered: movie underwhelming
#
# Original: The film was captivating
# Filtered: film captivating
#
# Original: The movie was a flop
# Filtered: movie flop
#
# Original: The film was enchanting
# Filtered: film enchanting
#
# Original: The movie was a disaster
# Filtered: movie disaster
#
# Original: The film was mesmerizing
# Filtered: film mesmerizing
#
# Original: The movie was a bore
# Filtered: movie bore
#
# Original: The film was a delight
# Filtered: film delight
#
# Original: The movie was a failure
# Filtered: movie failure
#
# Original: The film was a revelation
# Filtered: film revelation
#
# Original: The movie was tedious
# Filtered: movie tedious
#
# Original: The film was a gem
# Filtered: film gem
#
# Original: The movie was lackluster
# Filtered: movie lackluster
#
# Original: The film was a treasure
# Filtered: film treasure
#
# Original: The movie was disappointing
# Filtered: movie disappointing
#
# Original: The film was a marvel
# Filtered: film marvel
#
# Original: The movie was mediocre
# Filtered: movie mediocre
#
# Original: The film was a spectacle
# Filtered: film spectacle
#
# Original: The movie was substandard
# Filtered: movie substandard
#
# Original: The film was a wonder
# Filtered: film wonder
#
# Original: The movie was unimpressive
# Filtered: movie unimpressive
#
# Original: The film was a masterpiece
# Filtered: film masterpiece
#
# Original: The movie was forgettable
# Filtered: movie forgettable
#
# Original: The film was a tour de force
# Filtered: film tour de force
#
# Original: The movie was bland
# Filtered: movie bland
#
# Original: The film was a triumph
# Filtered: film triumph
#
# Original: The movie was uninspired
# Filtered: movie uninspired
#
# Original: The film was a joy
# Filtered: film joy
#
# Original: The movie was a letdown
# Filtered: movie letdown
#
# Original: The film was a revelation
# Filtered: film revelation
#
# Original: The movie was a disappointment
# Filtered: movie disappointment
#
# Original: The film was a delight
# Filtered: film delight
#
# Original: The movie was a failure
# Filtered: movie failure
#
# Original: The film was a marvel
# Filtered: film marvel
#
# Original: The movie was tedious
# Filtered: movie tedious
#
# Original: The film was a spectacle
# Filtered: film spectacle
#
# Original: The movie was dull
# Filtered: movie dull
#
# Original: The film was a wonder
# Filtered: film wonder
#
# Original: The movie was underwhelming
# Filtered: movie underwhelming
#
# Original: The film was a treasure
# Filtered: film treasure
#
# Original: The movie was lackluster
# Filtered: movie lackluster
#
# Original: The film was a gem
# Filtered: film gem
#
# Original: The movie was unimpressive
# Filtered: movie unimpressive
#
# Original: The film was a tour de force
# Filtered: film tour de force
#
# Original: The movie was substandard
# Filtered: movie substandard

# %%
# Aplicamos el procesamiento a los datos
featuresets = [({'text': remove_stopwords(text)}, label) for (text, label) in data]
print(featuresets)
# Out:
# [({'text': 'love movie'}, 'positive'), ({'text': 'movie terrible'}, 'negative'), ({'text': 'movie great'}, 'positive'), ({'text': 'dislike movie'}, 'negative'), ({'text': 'film amazing'}, 'positive'), ({'text': "ca n't stand watching movie"}, 'negative'), ({'text': 'acting movie phenomenal'}, 'positive'), ({'text': 'regret wasting time film'}, 'negative'), ({'text': 'thoroughly enjoyed movie'}, 'positive'), ({'text': 'movie lacks depth substance'}, 'negative'), ({'text': 'plot movie captivating'}, 'positive'), ({'text': 'found characters film engaging'}, 'positive'), ({'text': 'special effects movie impressive'}, 'positive'), ({'text': 'storyline predictable unoriginal'}, 'negative'), ({'text': 'disappointed lack character development'}, 'negative'), ({'text': 'cinematography film stunning'}, 'positive'), ({'text': 'dialogue felt forced unnatural'}, 'negative'), ({'text': 'pacing movie slow liking'}, 'negative'), ({'text': 'pleasantly surprised enjoyed film'}, 'positive'), ({'text': 'ending left feeling unsatisfied confused'}, 'negative'), ({'text': 'movie exceeded expectations'}, 'positive'), ({'text': 'performances actors lackluster'}, 'negative'), ({'text': 'film masterpiece'}, 'positive'), ({'text': "could n't wait movie end"}, 'negative'), ({'text': 'soundtrack movie beautiful'}, 'positive'), ({'text': 'plot twists predictable'}, 'negative'), ({'text': 'edge seat entire time'}, 'positive'), ({'text': 'movie complete waste time'}, 'negative'), ({'text': 'visuals film breathtaking'}, 'positive'), ({'text': 'characters one-dimensional'}, 'negative'), ({'text': 'would watch movie'}, 'positive'), ({'text': 'movie long boring'}, 'negative'), ({'text': 'director excellent job'}, 'positive'), ({'text': 'movie failed capture interest'}, 'negative'), ({'text': 'film powerful message'}, 'positive'), ({'text': 'acting subpar'}, 'negative'), ({'text': 'emotionally moved movie'}, 'positive'), ({'text': 'movie full clichés'}, 'negative'), ({'text': 'film visual feast'}, 'positive'), ({'text': 'plot hard follow'}, 'negative'), ({'text': 'highly recommend movie'}, 'positive'), ({'text': 'movie poorly executed'}, 'negative'), ({'text': 'film thought-provoking'}, 'positive'), ({'text': 'movie letdown'}, 'negative'), ({'text': 'performances outstanding'}, 'positive'), ({'text': 'movie forgettable'}, 'negative'), ({'text': 'film rollercoaster emotions'}, 'positive'), ({'text': 'movie lacked originality'}, 'negative'), ({'text': 'film beautifully shot'}, 'positive'), ({'text': 'movie disappointment'}, 'negative'), ({'text': 'film heartwarming'}, 'positive'), ({'text': 'movie poorly written'}, 'negative'), ({'text': 'film inspiring'}, 'positive'), ({'text': 'movie mess'}, 'negative'), ({'text': 'film joy watch'}, 'positive'), ({'text': 'movie confusing'}, 'negative'), ({'text': 'film triumph'}, 'positive'), ({'text': 'movie dull'}, 'negative'), ({'text': 'film work art'}, 'positive'), ({'text': 'movie underwhelming'}, 'negative'), ({'text': 'film captivating'}, 'positive'), ({'text': 'movie flop'}, 'negative'), ({'text': 'film enchanting'}, 'positive'), ({'text': 'movie disaster'}, 'negative'), ({'text': 'film mesmerizing'}, 'positive'), ({'text': 'movie bore'}, 'negative'), ({'text': 'film delight'}, 'positive'), ({'text': 'movie failure'}, 'negative'), ({'text': 'film revelation'}, 'positive'), ({'text': 'movie tedious'}, 'negative'), ({'text': 'film gem'}, 'positive'), ({'text': 'movie lackluster'}, 'negative'), ({'text': 'film treasure'}, 'positive'), ({'text': 'movie disappointing'}, 'negative'), ({'text': 'film marvel'}, 'positive'), ({'text': 'movie mediocre'}, 'negative'), ({'text': 'film spectacle'}, 'positive'), ({'text': 'movie substandard'}, 'negative'), ({'text': 'film wonder'}, 'positive'), ({'text': 'movie unimpressive'}, 'negative'), ({'text': 'film masterpiece'}, 'positive'), ({'text': 'movie forgettable'}, 'negative'), ({'text': 'film tour de force'}, 'positive'), ({'text': 'movie bland'}, 'negative'), ({'text': 'film triumph' ...

# %%
# preprocesamiento de texto con lematización en una matriz de datos
import nltk
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# Crear una función para lematizar
lemmatizer = WordNetLemmatizer()

def lemmatizar_texto(texto):
    palabras = word_tokenize(texto)
    palabras_lematizadas = [lemmatizer.lemmatize(palabra) for palabra in palabras]
    return ' '.join(palabras_lematizadas)

# Aplicar la función de lematización a cada comentario
data_lematizada = []
for comentario, etiqueta in data:
    comentario_lematizado = lemmatizar_texto(comentario)
    data_lematizada.append((comentario_lematizado, etiqueta))

# %%
# Une todos los textos lematizados
texto_lematizado = " ".join([texto for texto, _ in data_lematizada])

# Define stopwords
stopwords = set(STOPWORDS)

# Crea la nube de palabras
wordcloud = WordCloud(width=800, height=400, background_color="white", stopwords=stopwords).generate(texto_lematizado)

# Muestra la nube de palabras
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# Aplicamos el procesamiento a los datos
featuresets = [({"text": lemmatizar_texto(text)}, label) for (text, label) in data]
print(featuresets)
# Out:
# [({'text': 'I love this movie'}, 'positive'), ({'text': 'This movie is terrible'}, 'negative'), ({'text': 'This movie is great'}, 'positive'), ({'text': 'I dislike this movie'}, 'negative'), ({'text': 'This film is amazing'}, 'positive'), ({'text': "I ca n't stand watching this movie"}, 'negative'), ({'text': 'The acting in this movie is phenomenal'}, 'positive'), ({'text': 'I regret wasting my time on this film'}, 'negative'), ({'text': 'I thoroughly enjoyed this movie'}, 'positive'), ({'text': 'This movie lack depth and substance'}, 'negative'), ({'text': 'The plot of this movie wa captivating'}, 'positive'), ({'text': 'I found the character in this film to be very engaging'}, 'positive'), ({'text': 'The special effect in this movie were impressive'}, 'positive'), ({'text': 'The storyline wa predictable and unoriginal'}, 'negative'), ({'text': 'I wa disappointed by the lack of character development'}, 'negative'), ({'text': 'The cinematography in this film wa stunning'}, 'positive'), ({'text': 'The dialogue felt forced and unnatural'}, 'negative'), ({'text': 'The pacing of the movie wa too slow for my liking'}, 'negative'), ({'text': 'I wa pleasantly surprised by how I enjoyed this film'}, 'positive'), ({'text': 'The ending left me feeling unsatisfied and confused'}, 'negative'), ({'text': 'This movie exceeded my expectation'}, 'positive'), ({'text': 'The performance by the actor were lackluster'}, 'negative'), ({'text': 'This film is a masterpiece'}, 'positive'), ({'text': "I could n't wait for this movie to end"}, 'negative'), ({'text': 'The soundtrack of this movie wa beautiful'}, 'positive'), ({'text': 'The plot twist were very predictable'}, 'negative'), ({'text': 'I wa on the edge of my seat the entire time'}, 'positive'), ({'text': 'The movie wa a complete waste of time'}, 'negative'), ({'text': 'The visuals in this film were breathtaking'}, 'positive'), ({'text': 'The character were one-dimensional'}, 'negative'), ({'text': 'I would watch this movie again'}, 'positive'), ({'text': 'The movie wa too long and boring'}, 'negative'), ({'text': 'The director did an excellent job'}, 'positive'), ({'text': 'The movie failed to capture my interest'}, 'negative'), ({'text': 'The film had a powerful message'}, 'positive'), ({'text': 'The acting wa subpar'}, 'negative'), ({'text': 'I wa emotionally moved by this movie'}, 'positive'), ({'text': 'The movie wa full of clichés'}, 'negative'), ({'text': 'The film wa a visual feast'}, 'positive'), ({'text': 'The plot wa hard to follow'}, 'negative'), ({'text': 'I highly recommend this movie'}, 'positive'), ({'text': 'The movie wa poorly executed'}, 'negative'), ({'text': 'The film wa thought-provoking'}, 'positive'), ({'text': 'The movie wa a letdown'}, 'negative'), ({'text': 'The performance were outstanding'}, 'positive'), ({'text': 'The movie wa forgettable'}, 'negative'), ({'text': 'The film wa a rollercoaster of emotion'}, 'positive'), ({'text': 'The movie lacked originality'}, 'negative'), ({'text': 'The film wa beautifully shot'}, 'positive'), ({'text': 'The movie wa a disappointment'}, 'negative'), ({'text': 'The film wa heartwarming'}, 'positive'), ({'text': 'The movie wa poorly written'}, 'negative'), ({'text': 'The film wa inspiring'}, 'positive'), ({'text': 'The movie wa a mess'}, 'negative'), ({'text': 'The film wa a joy to watch'}, 'positive'), ({'text': 'The movie wa confusing'}, 'negative'), ({'text': 'The film wa a triumph'}, 'positive'), ({'text': 'The movie wa dull'}, 'negative'), ({'text': 'The film wa a work of art'}, 'positive'), ({'text': 'The movie wa underwhelming'}, 'negative'), ({'text': 'The film wa captivating'}, 'positive'), ({'text': 'The movie wa a flop'}, 'negative'), ({'text': 'The film wa enchanting'}, 'positive'), ({'text': 'The movie wa a disaster'}, 'negative'), ({'text': 'The film wa mesmerizing'}, 'positive'), ({'text': 'The movie wa a bore'}, 'negative'), ({'text': 'The film wa a delight'}, 'positive'), ({'text': 'The movie wa a failure'}, 'ne ...

# %%
# Dividimos los datos en conjuntos de entrenamiento y prueba
train_set, test_set = featuresets[:80], featuresets[80:]
print(train_set)
print(test_set)
# Out:
# [({'text': 'I love this movie'}, 'positive'), ({'text': 'This movie is terrible'}, 'negative'), ({'text': 'This movie is great'}, 'positive'), ({'text': 'I dislike this movie'}, 'negative'), ({'text': 'This film is amazing'}, 'positive'), ({'text': "I ca n't stand watching this movie"}, 'negative'), ({'text': 'The acting in this movie is phenomenal'}, 'positive'), ({'text': 'I regret wasting my time on this film'}, 'negative'), ({'text': 'I thoroughly enjoyed this movie'}, 'positive'), ({'text': 'This movie lack depth and substance'}, 'negative'), ({'text': 'The plot of this movie wa captivating'}, 'positive'), ({'text': 'I found the character in this film to be very engaging'}, 'positive'), ({'text': 'The special effect in this movie were impressive'}, 'positive'), ({'text': 'The storyline wa predictable and unoriginal'}, 'negative'), ({'text': 'I wa disappointed by the lack of character development'}, 'negative'), ({'text': 'The cinematography in this film wa stunning'}, 'positive'), ({'text': 'The dialogue felt forced and unnatural'}, 'negative'), ({'text': 'The pacing of the movie wa too slow for my liking'}, 'negative'), ({'text': 'I wa pleasantly surprised by how I enjoyed this film'}, 'positive'), ({'text': 'The ending left me feeling unsatisfied and confused'}, 'negative'), ({'text': 'This movie exceeded my expectation'}, 'positive'), ({'text': 'The performance by the actor were lackluster'}, 'negative'), ({'text': 'This film is a masterpiece'}, 'positive'), ({'text': "I could n't wait for this movie to end"}, 'negative'), ({'text': 'The soundtrack of this movie wa beautiful'}, 'positive'), ({'text': 'The plot twist were very predictable'}, 'negative'), ({'text': 'I wa on the edge of my seat the entire time'}, 'positive'), ({'text': 'The movie wa a complete waste of time'}, 'negative'), ({'text': 'The visuals in this film were breathtaking'}, 'positive'), ({'text': 'The character were one-dimensional'}, 'negative'), ({'text': 'I would watch this movie again'}, 'positive'), ({'text': 'The movie wa too long and boring'}, 'negative'), ({'text': 'The director did an excellent job'}, 'positive'), ({'text': 'The movie failed to capture my interest'}, 'negative'), ({'text': 'The film had a powerful message'}, 'positive'), ({'text': 'The acting wa subpar'}, 'negative'), ({'text': 'I wa emotionally moved by this movie'}, 'positive'), ({'text': 'The movie wa full of clichés'}, 'negative'), ({'text': 'The film wa a visual feast'}, 'positive'), ({'text': 'The plot wa hard to follow'}, 'negative'), ({'text': 'I highly recommend this movie'}, 'positive'), ({'text': 'The movie wa poorly executed'}, 'negative'), ({'text': 'The film wa thought-provoking'}, 'positive'), ({'text': 'The movie wa a letdown'}, 'negative'), ({'text': 'The performance were outstanding'}, 'positive'), ({'text': 'The movie wa forgettable'}, 'negative'), ({'text': 'The film wa a rollercoaster of emotion'}, 'positive'), ({'text': 'The movie lacked originality'}, 'negative'), ({'text': 'The film wa beautifully shot'}, 'positive'), ({'text': 'The movie wa a disappointment'}, 'negative'), ({'text': 'The film wa heartwarming'}, 'positive'), ({'text': 'The movie wa poorly written'}, 'negative'), ({'text': 'The film wa inspiring'}, 'positive'), ({'text': 'The movie wa a mess'}, 'negative'), ({'text': 'The film wa a joy to watch'}, 'positive'), ({'text': 'The movie wa confusing'}, 'negative'), ({'text': 'The film wa a triumph'}, 'positive'), ({'text': 'The movie wa dull'}, 'negative'), ({'text': 'The film wa a work of art'}, 'positive'), ({'text': 'The movie wa underwhelming'}, 'negative'), ({'text': 'The film wa captivating'}, 'positive'), ({'text': 'The movie wa a flop'}, 'negative'), ({'text': 'The film wa enchanting'}, 'positive'), ({'text': 'The movie wa a disaster'}, 'negative'), ({'text': 'The film wa mesmerizing'}, 'positive'), ({'text': 'The movie wa a bore'}, 'negative'), ({'text': 'The film wa a delight'}, 'positive'), ({'text': 'The movie wa a failure'}, 'ne ...
# [({'text': 'The film wa a masterpiece'}, 'positive'), ({'text': 'The movie wa forgettable'}, 'negative'), ({'text': 'The film wa a tour de force'}, 'positive'), ({'text': 'The movie wa bland'}, 'negative'), ({'text': 'The film wa a triumph'}, 'positive'), ({'text': 'The movie wa uninspired'}, 'negative'), ({'text': 'The film wa a joy'}, 'positive'), ({'text': 'The movie wa a letdown'}, 'negative'), ({'text': 'The film wa a revelation'}, 'positive'), ({'text': 'The movie wa a disappointment'}, 'negative'), ({'text': 'The film wa a delight'}, 'positive'), ({'text': 'The movie wa a failure'}, 'negative'), ({'text': 'The film wa a marvel'}, 'positive'), ({'text': 'The movie wa tedious'}, 'negative'), ({'text': 'The film wa a spectacle'}, 'positive'), ({'text': 'The movie wa dull'}, 'negative'), ({'text': 'The film wa a wonder'}, 'positive'), ({'text': 'The movie wa underwhelming'}, 'negative'), ({'text': 'The film wa a treasure'}, 'positive'), ({'text': 'The movie wa lackluster'}, 'negative'), ({'text': 'The film wa a gem'}, 'positive'), ({'text': 'The movie wa unimpressive'}, 'negative'), ({'text': 'The film wa a tour de force'}, 'positive'), ({'text': 'The movie wa substandard'}, 'negative')]

# %%
# Entrenamos el clasificador
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
# Evaluamos el clasificador en el conjunto de prueba
accuracy = nltk.classify.accuracy(classifier, test_set)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9166666666666666

# %%
# Clasificamos un nuevo texto
new_text = "This movie is terrible"
new_text_features = {"text": lemmatizar_texto(new_text)} # Wrap in a dictionary
predicted_label = classifier.classify(new_text_features)
print("Prediction:", predicted_label)

# Clasificamos un nuevo texto
new_text = "This movie is great"
new_text_features = {"text": lemmatizar_texto(new_text)} # Wrap in a dictionary
predicted_label = classifier.classify(new_text_features)
print("Prediction:", predicted_label)

# Clasificamos un nuevo texto
new_text = "I dislike this movie"
new_text_features = {"text": lemmatizar_texto(new_text)} # Wrap in a dictionary
predicted_label = classifier.classify(new_text_features)
print("Prediction:", predicted_label)

# Clasificamos un nuevo texto
new_text = "This film is amazing"
new_text_features = {"text": lemmatizar_texto(new_text)} # Wrap in a dictionary
predicted_label = classifier.classify(new_text_features)
print("Prediction:", predicted_label)
# Out:
# Prediction: negative
# Prediction: positive
# Prediction: negative
# Prediction: positive

# %%
#  algoritmo de clasificación disponible en NLTK el clasificador de árboles de decisión
#!pip install nltk
import nltk
nltk.download('punkt')

#  algoritmo de clasificación disponible en NLTK el clasificador de árboles de decisión
import nltk
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize

# Asumo que 'data' es una lista de tuplas (comentario, etiqueta)
comentarios = [c for c, _ in data]
etiquetas = [e for _, e in data]

# Vectorizamos los comentarios usando TF-IDF
vectorizer = TfidfVectorizer(tokenizer=word_tokenize)
X = vectorizer.fit_transform(comentarios)

# Dividimos los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, etiquetas, test_size=0.2, random_state=42)

# Creamos y entrenamos el clasificador de árboles de decisión
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

# Evaluamos la precisión en el conjunto de prueba
accuracy = clf.score(X_test, y_test)
print("Precisión:", accuracy)

# Evaluamos la precisión en el conjunto de entrenamiento
accuracy = clf.score(X_train, y_train)
print("Precisión:", accuracy)

# Ejemplo de cómo clasificar un nuevo comentario
nuevo_comentario = "This movie is amazing"
nuevo_comentario_vectorizado = vectorizer.transform([nuevo_comentario])
prediccion = clf.predict(nuevo_comentario_vectorizado)
print("Predicción:", prediccion[0])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Precisión: 0.8095238095238095
# Precisión: 1.0
# Predicción: negative

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import precision_score, recall_score, f1_score

def calcular_metricas(y_true, y_pred):
    # Calcular métricas de evaluación
    precision = precision_score(y_true, y_pred, pos_label='positive')
    recall = recall_score(y_true, y_pred, pos_label='positive')
    f1 = f1_score(y_true, y_pred, pos_label='positive')

    return {'precision': precision, 'recall': recall, 'f1_score': f1}

# data es una lista de tuplas (texto, etiqueta) y classifier es el clasificador entrenado
y_true = [etiqueta for _, etiqueta in data]
y_pred = [clf.predict(vectorizer.transform([texto]))[0] for texto, _ in data]

metricas = calcular_metricas(y_true, y_pred)
print(metricas)

# Matriz de confusión y_true y y_pred son las etiquetas verdaderas y predichas, respectivamente
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Negative', 'Positive'])
disp.plot()
plt.show()
# Out:
# {'precision': 1.0, 'recall': 0.9230769230769231, 'f1_score': 0.9600000000000001}

# %%
# Se obtienen las probabilidades de predicción para la clase positiva
y_probs = clf.predict_proba(vectorizer.transform([texto for texto, _ in data]))[:, 1]
# Se calculan los valores de FPR, TPR y umbrales
from sklearn.metrics import roc_curve
# Add pos_label here
fpr, tpr, thresholds = roc_curve(y_true, y_probs, pos_label='positive')
# Se crea la gráfica ROC
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py'>

# %%
#Gráfica de barras de errores
# Aplicamos el procesamiento a los datos
import numpy as np
featuresets = [({"text": lemmatizar_texto(text)}, label) for (text, label) in data]
print(featuresets)
errores_positivos = []
errores_negativos = []

for i in range(len(y_true)):
  if y_true[i] == 'positive' and y_pred[i] == 'negative':
    errores_positivos.append(1)
  elif y_true[i] == 'negative' and y_pred[i] == 'positive':
    errores_negativos.append(1)

total_positivos = y_true.count('positive')
total_negativos = y_true.count('negative')

tasa_error_positivos = np.sum(errores_positivos) / total_positivos
tasa_error_negativos = np.sum(errores_negativos) / total_negativos

import matplotlib.pyplot as plt

plt.bar(['Positivo', 'Negativo'], [tasa_error_positivos, tasa_error_negativos])
plt.xlabel('Clase')
plt.ylabel('Tasa de Error')
plt.title('Errores en la Predicción por Clase')
plt.show()
# Out:
# [({'text': 'I love this movie'}, 'positive'), ({'text': 'This movie is terrible'}, 'negative'), ({'text': 'This movie is great'}, 'positive'), ({'text': 'I dislike this movie'}, 'negative'), ({'text': 'This film is amazing'}, 'positive'), ({'text': "I ca n't stand watching this movie"}, 'negative'), ({'text': 'The acting in this movie is phenomenal'}, 'positive'), ({'text': 'I regret wasting my time on this film'}, 'negative'), ({'text': 'I thoroughly enjoyed this movie'}, 'positive'), ({'text': 'This movie lack depth and substance'}, 'negative'), ({'text': 'The plot of this movie wa captivating'}, 'positive'), ({'text': 'I found the character in this film to be very engaging'}, 'positive'), ({'text': 'The special effect in this movie were impressive'}, 'positive'), ({'text': 'The storyline wa predictable and unoriginal'}, 'negative'), ({'text': 'I wa disappointed by the lack of character development'}, 'negative'), ({'text': 'The cinematography in this film wa stunning'}, 'positive'), ({'text': 'The dialogue felt forced and unnatural'}, 'negative'), ({'text': 'The pacing of the movie wa too slow for my liking'}, 'negative'), ({'text': 'I wa pleasantly surprised by how I enjoyed this film'}, 'positive'), ({'text': 'The ending left me feeling unsatisfied and confused'}, 'negative'), ({'text': 'This movie exceeded my expectation'}, 'positive'), ({'text': 'The performance by the actor were lackluster'}, 'negative'), ({'text': 'This film is a masterpiece'}, 'positive'), ({'text': "I could n't wait for this movie to end"}, 'negative'), ({'text': 'The soundtrack of this movie wa beautiful'}, 'positive'), ({'text': 'The plot twist were very predictable'}, 'negative'), ({'text': 'I wa on the edge of my seat the entire time'}, 'positive'), ({'text': 'The movie wa a complete waste of time'}, 'negative'), ({'text': 'The visuals in this film were breathtaking'}, 'positive'), ({'text': 'The character were one-dimensional'}, 'negative'), ({'text': 'I would watch this movie again'}, 'positive'), ({'text': 'The movie wa too long and boring'}, 'negative'), ({'text': 'The director did an excellent job'}, 'positive'), ({'text': 'The movie failed to capture my interest'}, 'negative'), ({'text': 'The film had a powerful message'}, 'positive'), ({'text': 'The acting wa subpar'}, 'negative'), ({'text': 'I wa emotionally moved by this movie'}, 'positive'), ({'text': 'The movie wa full of clichés'}, 'negative'), ({'text': 'The film wa a visual feast'}, 'positive'), ({'text': 'The plot wa hard to follow'}, 'negative'), ({'text': 'I highly recommend this movie'}, 'positive'), ({'text': 'The movie wa poorly executed'}, 'negative'), ({'text': 'The film wa thought-provoking'}, 'positive'), ({'text': 'The movie wa a letdown'}, 'negative'), ({'text': 'The performance were outstanding'}, 'positive'), ({'text': 'The movie wa forgettable'}, 'negative'), ({'text': 'The film wa a rollercoaster of emotion'}, 'positive'), ({'text': 'The movie lacked originality'}, 'negative'), ({'text': 'The film wa beautifully shot'}, 'positive'), ({'text': 'The movie wa a disappointment'}, 'negative'), ({'text': 'The film wa heartwarming'}, 'positive'), ({'text': 'The movie wa poorly written'}, 'negative'), ({'text': 'The film wa inspiring'}, 'positive'), ({'text': 'The movie wa a mess'}, 'negative'), ({'text': 'The film wa a joy to watch'}, 'positive'), ({'text': 'The movie wa confusing'}, 'negative'), ({'text': 'The film wa a triumph'}, 'positive'), ({'text': 'The movie wa dull'}, 'negative'), ({'text': 'The film wa a work of art'}, 'positive'), ({'text': 'The movie wa underwhelming'}, 'negative'), ({'text': 'The film wa captivating'}, 'positive'), ({'text': 'The movie wa a flop'}, 'negative'), ({'text': 'The film wa enchanting'}, 'positive'), ({'text': 'The movie wa a disaster'}, 'negative'), ({'text': 'The film wa mesmerizing'}, 'positive'), ({'text': 'The movie wa a bore'}, 'negative'), ({'text': 'The film wa a delight'}, 'positive'), ({'text': 'The movie wa a failure'}, 'ne ...
