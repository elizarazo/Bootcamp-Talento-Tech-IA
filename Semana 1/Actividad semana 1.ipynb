# %% [markdown]
# Ejemplo Practico de python - Actividad 1
# Autor: Edgar Lizarazo

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create a dataset
# Let´s build the values lists
value_n_list = ['Jorge', 'Jaime', 'Luis']
print(value_n_list)

value_w_list = [70,         82,      89.5] # [kg]
value_h_list = [1.72,      1.69,     1.65] # [m]
# value_bmi_list will be calculated: bmi = w/(h^2)
#value_bmi_list = [25,25,25] # init values [kg/m2]

# Let´s use a dictionary ({key:value})
# with the format {"str":list}
data_dict = {"name":value_n_list,
             "weight":value_w_list,
             "height":value_h_list} #,
              #"BMI":value_bmi_list}

print(data_dict)

# Turn a dictionary into a dataframe
df = pd.DataFrame(data_dict)

print(df)
# Call a variable
df
# Out:
# ['Jorge', 'Jaime', 'Luis']
# {'name': ['Jorge', 'Jaime', 'Luis'], 'weight': [70, 82, 89.5], 'height': [1.72, 1.69, 1.65]}
#     name  weight  height
# 0  Jorge    70.0    1.72
# 1  Jaime    82.0    1.69
# 2   Luis    89.5    1.65
#     name  weight  height
# 0  Jorge    70.0    1.72
# 1  Jaime    82.0    1.69
# 2   Luis    89.5    1.65

# %%
r = 3+4

# %%
df
# Out:
#     name  weight  height
# 0  Jorge    70.0    1.72
# 1  Jaime    82.0    1.69
# 2   Luis    89.5    1.65

# %%
df
# Out:
#     name  weight  height
# 0  Jorge    70.0    1.72
# 1  Jaime    82.0    1.69
# 2   Luis    89.5    1.65
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['weight'].plot(kind='hist', bins=20, title='weight')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['height'].plot(kind='hist', bins=20, title='height')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='weight', y='height', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['weight']
#   ys = series['height']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('weight', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('weight')
# _ = plt.ylabel('height')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['weight']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'weight'}, axis=1)
#               .sort_values('weight', ascending=True))
#   xs = counted['weight']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = df.sort_values('weight', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('name')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='name', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('weight')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['weight'].plot(kind='line', figsize=(8, 4), title='weight')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['height'].plot(kind='line', figsize=(8, 4), title='height')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='weight', y='name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['name'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='height', y='name', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df
# Out:
#     name  weight  height
# 0  Jorge    70.0    1.72
# 1  Jaime    82.0    1.69
# 2   Luis    89.5    1.65

# %%
# prompt: Con DataFrame df: add another column

df['bmi'] = df['weight'] / (df['height'] ** 2)
df
# Out:
#     name  weight  height        bmi
# 0  Jorge    70.0    1.72  23.661439
# 1  Jaime    82.0    1.69  28.710479
# 2   Luis    89.5    1.65  32.874197

# %%
df.describe()
# Out:
#           weight    height        bmi
# count   3.000000  3.000000   3.000000
# mean   73.166667  1.773333  23.494564
# std    21.167979  0.090738   8.014020
# min    50.000000  1.690000  16.141529
# 25%    64.000000  1.725000  19.223500
# 50%    78.000000  1.760000  22.305471
# 75%    84.750000  1.815000  27.171082
# max    91.500000  1.870000  32.036693

# %% [markdown]
# ## Making some transformations on the df

# %%
# z = x / y*y
df["BMI"] =  df["weight"] / df["height"]**2
df
# Out:
#     name  weight  height        bmi        BMI
# 0  Jorge    70.0    1.72  23.661439  23.661439
# 1  Jaime    82.0    1.69  28.710479  28.710479
# 2   Luis    89.5    1.65  32.874197  32.874197

# %% [markdown]
# De acuerdo a los resultados puede conlcuir que:
#
# -El valor max es:
# -

# %%
df["BMI"].dtype
# Out:
# dtype('float64')

# %%
# TO-DO: create another column with integers and turn it to float, such as:
df["BMI"] = df["BMI"].astype(float)

# %%
df["BMI"].dtype
# Out:
# dtype('float64')

# %%
df["name"].dtype
# Homework: how to verify that a column contains string
# Out:
# dtype('O')

# %%
df
# Out:
#     name  weight  height        bmi        BMI
# 0  Jorge    70.0    1.72  23.661439  23.661439
# 1  Jaime    82.0    1.69  28.710479  28.710479
# 2   Luis    89.5    1.65  32.874197  32.874197

# %%
# Descriptive stats
df_stats = df.describe()
df_stats
# Out:
#           weight    height        bmi        BMI
# count   3.000000  3.000000   3.000000   3.000000
# mean   73.166667  1.773333  23.494564  23.494564
# std    21.167979  0.090738   8.014020   8.014020
# min    50.000000  1.690000  16.141529  16.141529
# 25%    64.000000  1.725000  19.223500  19.223500
# 50%    78.000000  1.760000  22.305471  22.305471
# 75%    84.750000  1.815000  27.171082  27.171082
# max    91.500000  1.870000  32.036693  32.036693

# %% [markdown]
# Ejemplos de estructuras cindicionales e iteractivas
# while
# For
# if else

# %%
marks = 80
result = ""
if marks < 30:
   result = "Failed"
elif marks > 75:
   result = "Passed with distinction"
else:
   result = "Passed"

print(result)
# Out:
# Passed with distinction

# %% [markdown]
# Ejemplo de sentencia case  en python

# %%
def checkVowel(n):
   match n:
      case 'a': return "Vowel alphabet"
      case 'e': return "Vowel alphabet"
      case 'i': return "Vowel alphabet"
      case 'o': return "Vowel alphabet"
      case 'u': return "Vowel alphabet"
      case _: return "Simple alphabet"
print (checkVowel('a'))
print (checkVowel('m'))
print (checkVowel('o'))
# Out:
# Vowel alphabet
# Simple alphabet
# Vowel alphabet

# %%
words = ["one", "two", "three"]
for x in words:
  print(x)
# Out:
# one
# two
# three

# %%
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5
